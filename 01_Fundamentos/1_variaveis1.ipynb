# %% [markdown]
# # Teoria

# %% [markdown]
# ## 1. Primeiro código

# %%
print('Hello, world')
# Out:
# Hello, world

# %% [markdown]
# ## 2. Variáveis

# %%
x = 10
nome = 'Matheus'
altura = 1.75

# %% [markdown]
# ## 3. Tipos básicos

# %%
int # inteiro
float # decimal
str # texto
bool # True ou False
# Out:
# bool

# %% [markdown]
# ### Exemplo

# %%
a = 5
b = 3.2
c = 'oi'

# %% [markdown]
# # Exercícios

# %% [markdown]
# ## 1. Crie um código que:
#
# ### - Mostre o seu nome
# ### - Mostre a sua idade

# %%
nome = 'Matheus'
idade = 32

print(nome)
print(idade)
# Out:
# Matheus
# 32

# %% [markdown]
# ## 2. Crie 3 variáveis:
#
# ### Uma inteira
# ### Uma decimal
# ### Uma string
#
# ### Depois imprima todas
#
# #### Faça isto três vezes

# %%
idade2 = 32
altura2 = 1.75
nome2 = 'Matheus'

print(idade2)
print(altura2)
print(nome2)
# Out:
# 32
# 1.75
# Matheus

# %%
print('Meu nome é', nome2, 'minha idade é', idade2, 'anos,',  'minha altura é', altura2, 'metros.')
# Out:
# Meu nome é Matheus minha idade é 32 anos, minha altura é 1.75 metros.

# %%
tempo = 7
distancia = 755.8
local = 'Pres. Prudente'

print(tempo)
print(distancia)
print(local)
# Out:
# 7
# 755.8
# Pres. Prudente

# %%
print('Da minha casa até', local, 'são', distancia, 'quilômetros.', 'A viagem terá duração de aproximadamente', tempo, 'horas.')
# Out:
# Da minha casa até Pres. Prudente são 755.8 quilômetros. A viagem terá duração de aproximadamente 7 horas.

# %%
profissao = 'engenheiro mecânico'
tempo2 = 9
reducao = 650.87

print(profissao)
print(tempo2)
print(reducao)
# Out:
# engenheiro mecânico
# 9
# 650.87

# %%
print('Sou', profissao, 'com experiencia de mais de', tempo2, 'e já gerei reduções de custos na ordem de', reducao, 'mil dólares.')
# Out:
# Sou engenheiro mecânico com experiencia de mais de 9 e já gerei reduções de custos na ordem de 650.87 mil dólares.

# %% [markdown]
# ## 3. Calcule a força

# %%
massa = 10 #kg
aceleracao = 1.4 #m/s2
forca = massa*aceleracao

print(forca, 'kgf')
# Out:
# 14.0 kgf

# %%
nomeeng = 'Matheus'
massa1 = 90
acel = 9.81
forca = massa1*acel

print('Nome do engenheiro:', nomeeng)
print('Força calculada:', forca, 'kgf')
# Out:
# Nome do engenheiro: Matheus
# Força calculada: 882.9000000000001 kgf

# %% [markdown]
# ## --- Exercícios complementares ---

# %%
diam = 40 #mm
pi = pi
area = diam**2 * pi / 4

print('A area é', area, 'mm2.')
# Out:
# A area é 1256.0 mm2

# %%
a = 2
b = 3
c = 4

delt = b**2 - 4*a*c

x1 = (-b+(delt)**(0.5))/2*a

x2 = (b+(delt)**(0.5))/2*a


print('As raízes da equação são:', x1, 'e', x2,)
# Out:
# As raízes das equações são: (-2.9999999999999996+4.795831523312719j) e (3.0000000000000004+4.795831523312719j)
