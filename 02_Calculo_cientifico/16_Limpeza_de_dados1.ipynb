# %% [markdown]
# ## 1. Problemas comuns em dados reais

# %%
# - Valores vazios
# - Espaços em branco
# - Colunas mal nomeadas
# - Tipos errados: string ao invés de número

# %% [markdown]
# ## 2. Verificando dados

# %%
print(df.info()) # mostra os tipos de dados

print(df.isnull().sum()) # mostra os valores nulos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rc/whb4tfm54hqcbdvw24vj88b80000gn/T/ipykernel_53260/1624558752.py in <module>
# ----> 1 print(df.info())
#       2
#       3 print(df.isnull().sum())
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 3. Remover valores nulos

# %%
df = df.dropna() #remove linhas com erro
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rc/whb4tfm54hqcbdvw24vj88b80000gn/T/ipykernel_53260/3743645053.py in <module>
# ----> 1 df = df.dropna() #remove linhas com erro
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 4. Preencher valores nulos

# %%
df["freq"] = df["freq"].fillna(df["freq"].mean()) #substiti por média de "freq"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rc/whb4tfm54hqcbdvw24vj88b80000gn/T/ipykernel_53260/2266591833.py in <module>
# ----> 1 df["freq"] = df["freq"].fillna(df["freq"].mean()) #substiti por média de "freq"
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 5. Converter tipos

# %%
df["freq"] = pd.to_numeric(df["freq"], errors = "coerce")

# Converte para número
# Valores inválidos vira NaN
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rc/whb4tfm54hqcbdvw24vj88b80000gn/T/ipykernel_53260/2137142291.py in <module>
# ----> 1 df["freq"] = pd.to_numeric(df["freq"], errors = "coerce")
#       2
#       3 # Converte para número
#       4 # Valores inválidos vira NaN
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## 6. Limpar texto

# %%
df["sensor"] = df["sensor"].str.strip().str.lower()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rc/whb4tfm54hqcbdvw24vj88b80000gn/T/ipykernel_53260/2395153558.py in <module>
# ----> 1 df["sensor"] = df["sensor"].str.strip().str.lower()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Fluxo operacional

# %%
# Ler ----> Inspecionar ----> Limpar ----> Analisar

# %%
import pandas as pd

df = pd.read_csv("2004-2021.tsv", sep= '\t')

print(df.head(2))
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09  2004-05-15  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                 1.350
# 1                  0.114                  0.89                 1.449
#
#   MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                0.463                     0.012                    0.825
# 1                0.399                     0.098                    0.763
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# ...

# %% [markdown]
# # Exercícios

# %% [markdown]
# ## 1. Detectar erro

# %%
print(df.isnull().sum())
# Out:
# DATA INICIAL                     0
# DATA FINAL                       0
# REGIÃO                           0
# ESTADO                           0
# PRODUTO                          0
# NÚMERO DE POSTOS PESQUISADOS     0
# UNIDADE DE MEDIDA                0
# PREÇO MÉDIO REVENDA              0
# DESVIO PADRÃO REVENDA            0
# PREÇO MÍNIMO REVENDA             0
# PREÇO MÁXIMO REVENDA             0
# MARGEM MÉDIA REVENDA             0
# COEF DE VARIAÇÃO REVENDA         0
# PREÇO MÉDIO DISTRIBUIÇÃO         0
# DESVIO PADRÃO DISTRIBUIÇÃO       0
# PREÇO MÍNIMO DISTRIBUIÇÃO        0
# PREÇO MÁXIMO DISTRIBUIÇÃO        0
# COEF DE VARIAÇÃO DISTRIBUIÇÃO    0
# dtype: int64

# %% [markdown]
# ## 2. Remover NaN

# %%
df = df.dropna()

# %% [markdown]
# ## 3. Converter dados

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120823 entries, 0 to 120822
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   120823 non-null  object
#  1   DATA FINAL                     120823 non-null  object
#  2   REGIÃO                         120823 non-null  object
#  3   ESTADO                         120823 non-null  object
#  4   PRODUTO                        120823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   120823 non-null  int64
#  6   UNIDADE DE MEDIDA              120823 non-null  object
#  7   PREÇO MÉDIO REVENDA            120823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          120823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           120823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           120823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           120823 non-null  object
# ...

# %%
df["COEF DE VARIAÇÃO REVENDA"] = pd.to_numeric(df["COEF DE VARIAÇÃO REVENDA"], errors = "coerce")

# %%
df["COEF DE VARIAÇÃO REVENDA"] = df["COEF DE VARIAÇÃO REVENDA"].fillna(df["COEF DE VARIAÇÃO REVENDA"].mean())

# %% [markdown]
# # 5. Mini desafio
# ### Limpar colunas
# ### Tratar valores inválidos
# ### Preparar análise

# %%
# Limpar colunas

df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

print(df.head(1))
# Out:
#   data_inicial  data_final        região            estado           produto  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
#
#    número_de_postos_pesquisados unidade_de_medida  preço_médio_revenda  \
# 0                           127              R$/l                1.288
#
#    desvio_padrão_revenda  preço_mínimo_revenda  preço_máximo_revenda  \
# 0                  0.016                  1.19                  1.35
#
#   margem_média_revenda  coef_de_variação_revenda preço_médio_distribuição  \
# 0                0.463                     0.012                    0.825
#
#   desvio_padrão_distribuição preço_mínimo_distribuição  \
# 0                       0.11                    0.4201
#
#   preço_máximo_distribuição coef_de_variação_distribuição
# 0                    0.9666                         0.133

# %%
# Aplicar conversão

df["preço_máximo_revenda"] = pd.to_numeric(df["preço_máximo_revenda"], errors = "coerce")

# %%
# Verificar valores nulos

print(df.isnull().sum())
# Out:
# data_inicial                     0
# data_final                       0
# região                           0
# estado                           0
# produto                          0
# número_de_postos_pesquisados     0
# unidade_de_medida                0
# preço_médio_revenda              0
# desvio_padrão_revenda            0
# preço_mínimo_revenda             0
# preço_máximo_revenda             0
# margem_média_revenda             0
# coef_de_variação_revenda         0
# preço_médio_distribuição         0
# desvio_padrão_distribuição       0
# preço_mínimo_distribuição        0
# preço_máximo_distribuição        0
# coef_de_variação_distribuição    0
# dtype: int64

# %%
# Remover linhas que contém erro

df = df.dropna()

# %%
# Analisar méida do preço_máximo_revenda

print("Média: ", df["preço_máximo_revenda"].mean())
# Out:
# Média:  13.233901966513516
